# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# **[NEW]** Mistral-fied Phi-3. [4bit model](https://huggingface.co/unsloth/Phi-3-mini-4k-instruct-bnb-4bit) and the [16bit model](https://huggingface.co/unsloth/Phi-3-mini-4k-instruct).

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.26" trl peft accelerate bitsandbytes

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen ([llamafied](https://huggingface.co/models?sort=trending&search=qwen+llama)), Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit", # Instruct version of Gemma 7b
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit", # Instruct version of Gemma 2b
    "unsloth/llama-3-8b-bnb-4bit", # [NEW] 15 Trillion token Llama-3
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-3-mini-4k-instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Unsloth: You passed in `unsloth/Phi-3-mini-4k-instruct` and `load_in_4bit = True`.
# We shall load `unsloth/Phi-3-mini-4k-instruct-bnb-4bit` for 4x faster loading.
# config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/140 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-50d4941685c9> in <cell line: 1>()
# ----> 1 model = FastLanguageModel.get_peft_model(
#       2     model,
#       3     r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
#       4     target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
#       5                       "gate_proj", "up_proj", "down_proj",],
#
# /usr/local/lib/python3.10/dist-packages/unsloth/models/llama.py in get_peft_model(model, r, target_modules, lora_alpha, lora_dropout, bias, layers_to_transform, layers_pattern, use_gradient_checkpointing, random_state, max_seq_length, use_rslora, modules_to_save, init_lora_weights, loftq_config, **kwargs)
#    1402
#    1403         if isinstance(model, PeftModelForCausalLM):
# -> 1404             raise TypeError(
#    1405                 "Unsloth: Your model already has LoRA adapters. No need to run this again!"
#    1406             )
#
# TypeError: Unsloth: Your model already has LoRA adapters. No need to run this again!

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `ChatML` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("deepanshdj/ossat1_8k_llama3", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Downloading readme:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.16M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8274 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8274 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['instruction', 'output', 'input', 'text'],
#     num_rows: 8274
# })

# %%
print(dataset['text'][0])
# Out:
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Can you write a short introduction about the relevance of the term "monopsony" in economics? Please use examples related to potential monopsonies in the labour market and cite relevant research.
#
# ### Input:
# None
#
# ### Response:
# "Monopsony" refers to a market structure where there is only one buyer for a particular good or service. In economics, this term is particularly relevant in the labor market, where a monopsony employer has significant power over the wages and working conditions of their employees. The presence of a monopsony can result in lower wages and reduced employment opportunities for workers, as the employer has little incentive to increase wages or provide better working conditions.
#
# Recent research has identified potential monopsonies in industries such as retail and fast food, where a few large companies control a significant portion of the market (Bivens & Mishel, 2013). In these industries, workers often face low wages, limited benefits, and reduced bargaining power, leading to a situation where they are dependent on the employer for their livelihood. This dependence can result in further suppression of wages and a decline in working conditions.
#
# Overall, the concept of monopsony is essential to understanding the dynamics of labor markets and the impact of market power on workers. Further research is needed to understand the extent and impact of monopsonies on the economy and to develop policies to address this issue.
#
# References:
# Bivens, J., & Mishel, L. (2013). The Pay of Corporate Executives and Financial Professionals as Evidence of Rents in Top 1 Percent Incomes. Journal of Economic Perspectives, 27(3), 57-78.<|endoftext|>

# %%
print(dataset['text'][44])
# Out:
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# It is a French joke, can you tell me more about the background.
#
# ### Input:
# None
#
# ### Response:
# The joke comes from the famous comedian, Gad Elmaleh, and the joke plays on the teaching method used in French schools for learning English throughout the 80s and into the 90s.
# The joke from his sketch goes like this (translated into English) :
#
# ```Because I know a little English too, I learned English in school when I was little like all of you.
# We all had the same dumb class!
# With that famous existential question that you just had to find an answer to: “Where is Brian?”
# Brian traumatized all of you as well…
# You didn’t know who Brian was, you didn’t care, but you had to find out where he was in the house in order to learn English, that was it.
# You had to find the members of Brian’s family in order to learn English, and what happened?
# “Where is Brian?” and like an idiot you calmly responded: “Brian is in the kitchen”…```
#
# Here is a YouTube video of the original routine, if you're interested: https://www.youtube.com/watch?v=7SSkObIf9Ic<|endoftext|>

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/8274 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 2.283 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 8,274 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 60
#  "-____-"     Number of trainable parameters = 29,884,416
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 06:33, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.329000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.413500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.700600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.529800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.302300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.883700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.281400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.063500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.080700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.292500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.134000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.078100</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.078900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.113400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.976800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.150300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.156500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.004000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.318600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.264200</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.009200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.932900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.035100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.867100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.792500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.819300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.163900</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.994500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.951000</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.983600</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.013200</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.920500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.289500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.304600</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.030300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.478500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.691300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.157400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.987400</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.011700</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.254700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.908300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.012400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.827200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.849200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.416500</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.009300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.931200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.737200</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.008900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.823800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.769900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.872300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.866900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.054300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.184700</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.053100</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.973500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.490300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
trainer_stats.metrics
# Out:
# {'train_runtime': 409.2287,
#  'train_samples_per_second': 1.173,
#  'train_steps_per_second': 0.147,
#  'total_flos': 4761876003840000.0,
#  'train_loss': 1.0762348701556523,
#  'epoch': 0.05801305293691081}

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 409.2287 seconds used for training.
# 6.82 minutes used for training.
# Peak reserved memory = 3.314 GB.
# Peak reserved memory for training = 1.031 GB.
# Peak reserved memory % of max memory = 22.471 %.
# Peak reserved memory for training % of max memory = 6.991 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
print(tokenizer.batch_decode(outputs)[0])
# Out:
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Continue the fibonnaci sequence.
#
# ### Input:
# 1, 1, 2, 3, 5, 8
#
# ### Response:
# 13, 21, 34, 55, 89, 144, 233, 377, 610, 987, 1597, 2584, 4181, 6

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Continue the fibonnaci sequence.
#
# ### Input:
# 1, 1, 2, 3, 5, 8
#
# ### Response:
# 13, 21, 34, 55, 89, 144, 233, 377, 610, 987, 1597, 2584, 4181, 6765, 10946, 17711, 28657, 46368, 75025, 121393, 196418, 317845,

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.model',
#  'lora_model/added_tokens.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# alpaca_prompt = You MUST copy from above!

inputs = tokenizer(
[
    alpaca_prompt.format(
        "What is a famous tall tower in Paris?", # instruction
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
# Out:
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
print(tokenizer.batch_decode(outputs)[0])
# Out:
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# What is a famous tall tower in Paris?
#
# ### Input:
#
#
# ### Response:
# The Eiffel Tower is a famous tall tower in Paris. It was built in 1889 and stands at a height of 324 meters (1,063 feet). The tower is made of iron and was originally built as a temporary structure for the 1889 World'

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if True: model.push_to_hub_merged("deepanshdj/dj-phi-3_3.8b-16bit", tokenizer, save_method = "merged_16bit", token = "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")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")
# Out:
# Unsloth: You are pushing to hub, but you passed your HF username = deepanshdj.
# We shall truncate deepanshdj/dj-phi-3_3.8b-16bit to dj-phi-3_3.8b-16bit
# Unsloth: You have 1 CPUs. Using `safe_serialization` is 10x slower.
# We shall switch to Pytorch saving, which will take 3 minutes and not 30 minutes.
# To force `safe_serialization`, set it to `None` instead.
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 2.3G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 4.62 out of 12.67 RAM for saving.
#  88%|████████▊ | 28/32 [00:01<00:00, 26.60it/s]We will save to Disk and not RAM now.
# 100%|██████████| 32/32 [00:04<00:00,  7.65it/s]
# Unsloth: Saving tokenizer...
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
#  Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Unsloth: Saving dj-phi-3_3.8b-16bit/pytorch_model-00001-of-00002.bin...
# Unsloth: Saving dj-phi-3_3.8b-16bit/pytorch_model-00002-of-00002.bin...
# README.md:   0%|          | 0.00/605 [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/2.65G [00:00<?, ?B/s]
# Done.
# Saved merged model to https://huggingface.co/deepanshdj/dj-phi-3_3.8b-16bit

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if True: model.push_to_hub_gguf("deepanshdj/dj-phi-3-F16-GGUF", tokenizer, quantization_method = "f16", token = "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")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")
# Out:
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 4.46 out of 12.67 RAM for saving.
# 100%|██████████| 32/32 [00:01<00:00, 18.27it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Unsloth: Saving deepanshdj/dj-phi-3-F16-GGUF/pytorch_model-00001-of-00002.bin...
# Unsloth: Saving deepanshdj/dj-phi-3-F16-GGUF/pytorch_model-00002-of-00002.bin...
# Done.
# Unsloth: Converting mistral model. Can use fast conversion = True.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp will take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GUUF 16bits will take 3 minutes.
# \        /    [2] Converting GGUF 16bits to f16 will take 20 minutes.
#  "-____-"     In total, you will have to wait around 26 minutes.
#
# Unsloth: [0] Installing llama.cpp. This will take 3 minutes...
# Unsloth: Extending deepanshdj/dj-phi-3-F16-GGUF/tokenizer.model with added_tokens.json.
# Originally tokenizer.model is of size (32000).
# But we need to extend to sentencepiece vocab size (32011).
# Unsloth: [1] Converting model at deepanshdj/dj-phi-3-F16-GGUF into f16 GGUF format.
# The output location will be ./deepanshdj/dj-phi-3-F16-GGUF-unsloth.F16.gguf
# This will take 3 minutes...
# INFO:convert:Loading model file deepanshdj/dj-phi-3-F16-GGUF/pytorch_model-00001-of-00002.bin
# INFO:convert:Loading model file deepanshdj/dj-phi-3-F16-GGUF/pytorch_model-00001-of-00002.bin
# INFO:convert:Loading model file deepanshdj/dj-phi-3-F16-GGUF/pytorch_model-00002-of-00002.bin
# INFO:convert:model parameters count : 3821079552 (4B)
# INFO:convert:params = Params(n_vocab=32064, n_embd=3072, n_layer=32, n_ctx=4096, n_ff=8192, n_head=32, n_head_kv=32, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('deepanshdj/dj-phi-3-F16-GGUF'))
# INFO:convert:Loaded vocab file PosixPath('deepanshdj/dj-phi-3-F16-GGUF/tokenizer.model'), type 'spm'
# INFO:convert:Vocab info: <SentencePieceVocab with 32011 base tokens and 0 added tokens>
# INFO:convert:Special vocab info: <SpecialVocab with 0 merges, special tokens {'bos': 1, 'eos': 32000, 'unk': 0, 'pad': 32009}, add special tokens {'bos': True, 'eos': False}>
# INFO:convert:Writing deepanshdj/dj-phi-3-F16-GGUF-unsloth.F16.gguf, format 1
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 32000
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 32009
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting chat_template to {{ bos_token }}{% for message in messages %}{% if (message['role'] == 'user') %}{{'<|user|>' + '
# ' + message['content'] + '<|end|>' + '
# ' + '<|assistant|>' + '
# '}}{% elif (message['role'] == 'assistant') %}{{message['content'] + '<|end|>' + '
# '}}{% endif %}{% endfor %}
# INFO:convert:[  1/291] Writing tensor token_embd.weight                      | size  32064 x   3072  | type F16  | T+   1
# INFO:convert:[  2/291] Writing tensor blk.0.attn_q.weight                    | size   3072 x   3072  | type F16  | T+   4
# INFO:convert:[  3/291] Writing tensor blk.0.attn_k.weight                    | size   3072 x   3072  | type F16  | T+   4
# INFO:convert:[  4/291] Writing tensor blk.0.attn_v.weight                    | size   3072 x   3072  | type F16  | T+   4
# INFO:convert:[  5/291] Writing tensor blk.0.attn_output.weight               | size   3072 x   3072  | type F16  | T+   4
# INFO:convert:[  6/291] Writing tensor blk.0.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+   6
# INFO:convert:[  7/291] Writing tensor blk.0.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+   6
# INFO:convert:[  8/291] Writing tensor blk.0.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+   7
# INFO:convert:[  9/291] Writing tensor blk.0.attn_norm.weight                 | size   3072           | type F32  | T+   7
# INFO:convert:[ 10/291] Writing tensor blk.0.ffn_norm.weight                  | size   3072           | type F32  | T+   7
# INFO:convert:[ 11/291] Writing tensor blk.1.attn_q.weight                    | size   3072 x   3072  | type F16  | T+   7
# INFO:convert:[ 12/291] Writing tensor blk.1.attn_k.weight                    | size   3072 x   3072  | type F16  | T+   7
# INFO:convert:[ 13/291] Writing tensor blk.1.attn_v.weight                    | size   3072 x   3072  | type F16  | T+   7
# INFO:convert:[ 14/291] Writing tensor blk.1.attn_output.weight               | size   3072 x   3072  | type F16  | T+  12
# INFO:convert:[ 15/291] Writing tensor blk.1.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  12
# INFO:convert:[ 16/291] Writing tensor blk.1.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  12
# INFO:convert:[ 17/291] Writing tensor blk.1.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  15
# INFO:convert:[ 18/291] Writing tensor blk.1.attn_norm.weight                 | size   3072           | type F32  | T+  18
# INFO:convert:[ 19/291] Writing tensor blk.1.ffn_norm.weight                  | size   3072           | type F32  | T+  18
# INFO:convert:[ 20/291] Writing tensor blk.2.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  18
# INFO:convert:[ 21/291] Writing tensor blk.2.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  18
# INFO:convert:[ 22/291] Writing tensor blk.2.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  18
# INFO:convert:[ 23/291] Writing tensor blk.2.attn_output.weight               | size   3072 x   3072  | type F16  | T+  18
# INFO:convert:[ 24/291] Writing tensor blk.2.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  18
# INFO:convert:[ 25/291] Writing tensor blk.2.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  19
# INFO:convert:[ 26/291] Writing tensor blk.2.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  20
# INFO:convert:[ 27/291] Writing tensor blk.2.attn_norm.weight                 | size   3072           | type F32  | T+  24
# INFO:convert:[ 28/291] Writing tensor blk.2.ffn_norm.weight                  | size   3072           | type F32  | T+  24
# INFO:convert:[ 29/291] Writing tensor blk.3.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  24
# INFO:convert:[ 30/291] Writing tensor blk.3.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  24
# INFO:convert:[ 31/291] Writing tensor blk.3.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  24
# INFO:convert:[ 32/291] Writing tensor blk.3.attn_output.weight               | size   3072 x   3072  | type F16  | T+  25
# INFO:convert:[ 33/291] Writing tensor blk.3.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  25
# INFO:convert:[ 34/291] Writing tensor blk.3.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  25
# INFO:convert:[ 35/291] Writing tensor blk.3.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  30
# INFO:convert:[ 36/291] Writing tensor blk.3.attn_norm.weight                 | size   3072           | type F32  | T+  30
# INFO:convert:[ 37/291] Writing tensor blk.3.ffn_norm.weight                  | size   3072           | type F32  | T+  30
# INFO:convert:[ 38/291] Writing tensor blk.4.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  30
# INFO:convert:[ 39/291] Writing tensor blk.4.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  30
# INFO:convert:[ 40/291] Writing tensor blk.4.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  31
# INFO:convert:[ 41/291] Writing tensor blk.4.attn_output.weight               | size   3072 x   3072  | type F16  | T+  31
# INFO:convert:[ 42/291] Writing tensor blk.4.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  31
# INFO:convert:[ 43/291] Writing tensor blk.4.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  34
# INFO:convert:[ 44/291] Writing tensor blk.4.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  34
# INFO:convert:[ 45/291] Writing tensor blk.4.attn_norm.weight                 | size   3072           | type F32  | T+  34
# INFO:convert:[ 46/291] Writing tensor blk.4.ffn_norm.weight                  | size   3072           | type F32  | T+  34
# INFO:convert:[ 47/291] Writing tensor blk.5.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  34
# INFO:convert:[ 48/291] Writing tensor blk.5.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  35
# INFO:convert:[ 49/291] Writing tensor blk.5.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  35
# INFO:convert:[ 50/291] Writing tensor blk.5.attn_output.weight               | size   3072 x   3072  | type F16  | T+  36
# INFO:convert:[ 51/291] Writing tensor blk.5.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  36
# INFO:convert:[ 52/291] Writing tensor blk.5.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  36
# INFO:convert:[ 53/291] Writing tensor blk.5.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  43
# INFO:convert:[ 54/291] Writing tensor blk.5.attn_norm.weight                 | size   3072           | type F32  | T+  43
# INFO:convert:[ 55/291] Writing tensor blk.5.ffn_norm.weight                  | size   3072           | type F32  | T+  43
# INFO:convert:[ 56/291] Writing tensor blk.6.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  43
# INFO:convert:[ 57/291] Writing tensor blk.6.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  43
# INFO:convert:[ 58/291] Writing tensor blk.6.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  43
# INFO:convert:[ 59/291] Writing tensor blk.6.attn_output.weight               | size   3072 x   3072  | type F16  | T+  44
# INFO:convert:[ 60/291] Writing tensor blk.6.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  44
# INFO:convert:[ 61/291] Writing tensor blk.6.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  44
# INFO:convert:[ 62/291] Writing tensor blk.6.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  48
# INFO:convert:[ 63/291] Writing tensor blk.6.attn_norm.weight                 | size   3072           | type F32  | T+  48
# INFO:convert:[ 64/291] Writing tensor blk.6.ffn_norm.weight                  | size   3072           | type F32  | T+  48
# INFO:convert:[ 65/291] Writing tensor blk.7.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  48
# INFO:convert:[ 66/291] Writing tensor blk.7.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  48
# INFO:convert:[ 67/291] Writing tensor blk.7.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  48
# INFO:convert:[ 68/291] Writing tensor blk.7.attn_output.weight               | size   3072 x   3072  | type F16  | T+  48
# INFO:convert:[ 69/291] Writing tensor blk.7.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  49
# INFO:convert:[ 70/291] Writing tensor blk.7.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  54
# INFO:convert:[ 71/291] Writing tensor blk.7.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  54
# INFO:convert:[ 72/291] Writing tensor blk.7.attn_norm.weight                 | size   3072           | type F32  | T+  54
# INFO:convert:[ 73/291] Writing tensor blk.7.ffn_norm.weight                  | size   3072           | type F32  | T+  54
# INFO:convert:[ 74/291] Writing tensor blk.8.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  54
# INFO:convert:[ 75/291] Writing tensor blk.8.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  54
# INFO:convert:[ 76/291] Writing tensor blk.8.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  55
# INFO:convert:[ 77/291] Writing tensor blk.8.attn_output.weight               | size   3072 x   3072  | type F16  | T+  55
# INFO:convert:[ 78/291] Writing tensor blk.8.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  55
# INFO:convert:[ 79/291] Writing tensor blk.8.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  55
# INFO:convert:[ 80/291] Writing tensor blk.8.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  60
# INFO:convert:[ 81/291] Writing tensor blk.8.attn_norm.weight                 | size   3072           | type F32  | T+  60
# INFO:convert:[ 82/291] Writing tensor blk.8.ffn_norm.weight                  | size   3072           | type F32  | T+  60
# INFO:convert:[ 83/291] Writing tensor blk.9.attn_q.weight                    | size   3072 x   3072  | type F16  | T+  60
# INFO:convert:[ 84/291] Writing tensor blk.9.attn_k.weight                    | size   3072 x   3072  | type F16  | T+  60
# INFO:convert:[ 85/291] Writing tensor blk.9.attn_v.weight                    | size   3072 x   3072  | type F16  | T+  60
# INFO:convert:[ 86/291] Writing tensor blk.9.attn_output.weight               | size   3072 x   3072  | type F16  | T+  60
# INFO:convert:[ 87/291] Writing tensor blk.9.ffn_gate.weight                  | size   8192 x   3072  | type F16  | T+  61
# INFO:convert:[ 88/291] Writing tensor blk.9.ffn_up.weight                    | size   8192 x   3072  | type F16  | T+  61
# INFO:convert:[ 89/291] Writing tensor blk.9.ffn_down.weight                  | size   3072 x   8192  | type F16  | T+  62
# INFO:convert:[ 90/291] Writing tensor blk.9.attn_norm.weight                 | size   3072           | type F32  | T+  65
# INFO:convert:[ 91/291] Writing tensor blk.9.ffn_norm.weight                  | size   3072           | type F32  | T+  65
# INFO:convert:[ 92/291] Writing tensor blk.10.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  65
# INFO:convert:[ 93/291] Writing tensor blk.10.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  65
# INFO:convert:[ 94/291] Writing tensor blk.10.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  65
# INFO:convert:[ 95/291] Writing tensor blk.10.attn_output.weight              | size   3072 x   3072  | type F16  | T+  65
# INFO:convert:[ 96/291] Writing tensor blk.10.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  66
# INFO:convert:[ 97/291] Writing tensor blk.10.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  66
# INFO:convert:[ 98/291] Writing tensor blk.10.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  67
# INFO:convert:[ 99/291] Writing tensor blk.10.attn_norm.weight                | size   3072           | type F32  | T+  71
# INFO:convert:[100/291] Writing tensor blk.10.ffn_norm.weight                 | size   3072           | type F32  | T+  71
# INFO:convert:[101/291] Writing tensor blk.11.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  71
# INFO:convert:[102/291] Writing tensor blk.11.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  71
# INFO:convert:[103/291] Writing tensor blk.11.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  71
# INFO:convert:[104/291] Writing tensor blk.11.attn_output.weight              | size   3072 x   3072  | type F16  | T+  71
# INFO:convert:[105/291] Writing tensor blk.11.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  72
# INFO:convert:[106/291] Writing tensor blk.11.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  73
# INFO:convert:[107/291] Writing tensor blk.11.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  73
# INFO:convert:[108/291] Writing tensor blk.11.attn_norm.weight                | size   3072           | type F32  | T+  73
# INFO:convert:[109/291] Writing tensor blk.11.ffn_norm.weight                 | size   3072           | type F32  | T+  73
# INFO:convert:[110/291] Writing tensor blk.12.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  73
# INFO:convert:[111/291] Writing tensor blk.12.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  76
# INFO:convert:[112/291] Writing tensor blk.12.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  76
# INFO:convert:[113/291] Writing tensor blk.12.attn_output.weight              | size   3072 x   3072  | type F16  | T+  77
# INFO:convert:[114/291] Writing tensor blk.12.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  77
# INFO:convert:[115/291] Writing tensor blk.12.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  77
# INFO:convert:[116/291] Writing tensor blk.12.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  78
# INFO:convert:[117/291] Writing tensor blk.12.attn_norm.weight                | size   3072           | type F32  | T+  78
# INFO:convert:[118/291] Writing tensor blk.12.ffn_norm.weight                 | size   3072           | type F32  | T+  78
# INFO:convert:[119/291] Writing tensor blk.13.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  78
# INFO:convert:[120/291] Writing tensor blk.13.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  78
# INFO:convert:[121/291] Writing tensor blk.13.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  78
# INFO:convert:[122/291] Writing tensor blk.13.attn_output.weight              | size   3072 x   3072  | type F16  | T+  78
# INFO:convert:[123/291] Writing tensor blk.13.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  79
# INFO:convert:[124/291] Writing tensor blk.13.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  79
# INFO:convert:[125/291] Writing tensor blk.13.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  83
# INFO:convert:[126/291] Writing tensor blk.13.attn_norm.weight                | size   3072           | type F32  | T+  83
# INFO:convert:[127/291] Writing tensor blk.13.ffn_norm.weight                 | size   3072           | type F32  | T+  83
# INFO:convert:[128/291] Writing tensor blk.14.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  83
# INFO:convert:[129/291] Writing tensor blk.14.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  84
# INFO:convert:[130/291] Writing tensor blk.14.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  84
# INFO:convert:[131/291] Writing tensor blk.14.attn_output.weight              | size   3072 x   3072  | type F16  | T+  84
# INFO:convert:[132/291] Writing tensor blk.14.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  84
# INFO:convert:[133/291] Writing tensor blk.14.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  85
# INFO:convert:[134/291] Writing tensor blk.14.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  90
# INFO:convert:[135/291] Writing tensor blk.14.attn_norm.weight                | size   3072           | type F32  | T+  90
# INFO:convert:[136/291] Writing tensor blk.14.ffn_norm.weight                 | size   3072           | type F32  | T+  90
# INFO:convert:[137/291] Writing tensor blk.15.attn_q.weight                   | size   3072 x   3072  | type F16  | T+  90
# INFO:convert:[138/291] Writing tensor blk.15.attn_k.weight                   | size   3072 x   3072  | type F16  | T+  92
# INFO:convert:[139/291] Writing tensor blk.15.attn_v.weight                   | size   3072 x   3072  | type F16  | T+  93
# INFO:convert:[140/291] Writing tensor blk.15.attn_output.weight              | size   3072 x   3072  | type F16  | T+  96
# INFO:convert:[141/291] Writing tensor blk.15.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+  96
# INFO:convert:[142/291] Writing tensor blk.15.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+  96
# INFO:convert:[143/291] Writing tensor blk.15.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+  96
# INFO:convert:[144/291] Writing tensor blk.15.attn_norm.weight                | size   3072           | type F32  | T+ 102
# INFO:convert:[145/291] Writing tensor blk.15.ffn_norm.weight                 | size   3072           | type F32  | T+ 102
# INFO:convert:[146/291] Writing tensor blk.16.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 102
# INFO:convert:[147/291] Writing tensor blk.16.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 102
# INFO:convert:[148/291] Writing tensor blk.16.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 102
# INFO:convert:[149/291] Writing tensor blk.16.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 102
# INFO:convert:[150/291] Writing tensor blk.16.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 102
# INFO:convert:[151/291] Writing tensor blk.16.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 103
# INFO:convert:[152/291] Writing tensor blk.16.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 108
# INFO:convert:[153/291] Writing tensor blk.16.attn_norm.weight                | size   3072           | type F32  | T+ 108
# INFO:convert:[154/291] Writing tensor blk.16.ffn_norm.weight                 | size   3072           | type F32  | T+ 108
# INFO:convert:[155/291] Writing tensor blk.17.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 108
# INFO:convert:[156/291] Writing tensor blk.17.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 108
# INFO:convert:[157/291] Writing tensor blk.17.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 108
# INFO:convert:[158/291] Writing tensor blk.17.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 108
# INFO:convert:[159/291] Writing tensor blk.17.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 109
# INFO:convert:[160/291] Writing tensor blk.17.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 109
# INFO:convert:[161/291] Writing tensor blk.17.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 112
# INFO:convert:[162/291] Writing tensor blk.17.attn_norm.weight                | size   3072           | type F32  | T+ 112
# INFO:convert:[163/291] Writing tensor blk.17.ffn_norm.weight                 | size   3072           | type F32  | T+ 112
# INFO:convert:[164/291] Writing tensor blk.18.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 112
# INFO:convert:[165/291] Writing tensor blk.18.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 112
# INFO:convert:[166/291] Writing tensor blk.18.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 112
# INFO:convert:[167/291] Writing tensor blk.18.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 113
# INFO:convert:[168/291] Writing tensor blk.18.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 113
# INFO:convert:[169/291] Writing tensor blk.18.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 114
# INFO:convert:[170/291] Writing tensor blk.18.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 114
# INFO:convert:[171/291] Writing tensor blk.18.attn_norm.weight                | size   3072           | type F32  | T+ 118
# INFO:convert:[172/291] Writing tensor blk.18.ffn_norm.weight                 | size   3072           | type F32  | T+ 118
# INFO:convert:[173/291] Writing tensor blk.19.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 118
# INFO:convert:[174/291] Writing tensor blk.19.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 118
# INFO:convert:[175/291] Writing tensor blk.19.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 118
# INFO:convert:[176/291] Writing tensor blk.19.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 118
# INFO:convert:[177/291] Writing tensor blk.19.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 119
# INFO:convert:[178/291] Writing tensor blk.19.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 119
# INFO:convert:[179/291] Writing tensor blk.19.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 120
# INFO:convert:[180/291] Writing tensor blk.19.attn_norm.weight                | size   3072           | type F32  | T+ 123
# INFO:convert:[181/291] Writing tensor blk.19.ffn_norm.weight                 | size   3072           | type F32  | T+ 123
# INFO:convert:[182/291] Writing tensor blk.20.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 123
# INFO:convert:[183/291] Writing tensor blk.20.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 123
# INFO:convert:[184/291] Writing tensor blk.20.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 123
# INFO:convert:[185/291] Writing tensor blk.20.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 123
# INFO:convert:[186/291] Writing tensor blk.20.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 124
# INFO:convert:[187/291] Writing tensor blk.20.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 124
# INFO:convert:[188/291] Writing tensor blk.20.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 125
# INFO:convert:[189/291] Writing tensor blk.20.attn_norm.weight                | size   3072           | type F32  | T+ 129
# INFO:convert:[190/291] Writing tensor blk.20.ffn_norm.weight                 | size   3072           | type F32  | T+ 129
# INFO:convert:[191/291] Writing tensor blk.21.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 129
# INFO:convert:[192/291] Writing tensor blk.21.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 129
# INFO:convert:[193/291] Writing tensor blk.21.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 129
# INFO:convert:[194/291] Writing tensor blk.21.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 129
# INFO:convert:[195/291] Writing tensor blk.21.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 130
# INFO:convert:[196/291] Writing tensor blk.21.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 130
# INFO:convert:[197/291] Writing tensor blk.21.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 130
# INFO:convert:[198/291] Writing tensor blk.21.attn_norm.weight                | size   3072           | type F32  | T+ 130
# INFO:convert:[199/291] Writing tensor blk.21.ffn_norm.weight                 | size   3072           | type F32  | T+ 130
# INFO:convert:[200/291] Writing tensor blk.22.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 130
# INFO:convert:[201/291] Writing tensor blk.22.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 131
# INFO:convert:[202/291] Writing tensor blk.22.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 131
# INFO:convert:[203/291] Writing tensor blk.22.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 131
# INFO:convert:[204/291] Writing tensor blk.22.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 132
# INFO:convert:[205/291] Writing tensor blk.22.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 135
# INFO:convert:[206/291] Writing tensor blk.22.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 135
# INFO:convert:[207/291] Writing tensor blk.22.attn_norm.weight                | size   3072           | type F32  | T+ 141
# INFO:convert:[208/291] Writing tensor blk.22.ffn_norm.weight                 | size   3072           | type F32  | T+ 141
# INFO:convert:[209/291] Writing tensor blk.23.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 141
# INFO:convert:[210/291] Writing tensor blk.23.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 145
# INFO:convert:[211/291] Writing tensor blk.23.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 145
# INFO:convert:[212/291] Writing tensor blk.23.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 145
# INFO:convert:[213/291] Writing tensor blk.23.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 145
# INFO:convert:[214/291] Writing tensor blk.23.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 146
# INFO:convert:[215/291] Writing tensor blk.23.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 151
# INFO:convert:[216/291] Writing tensor blk.23.attn_norm.weight                | size   3072           | type F32  | T+ 151
# INFO:convert:[217/291] Writing tensor blk.23.ffn_norm.weight                 | size   3072           | type F32  | T+ 151
# INFO:convert:[218/291] Writing tensor blk.24.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 151
# INFO:convert:[219/291] Writing tensor blk.24.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 151
# INFO:convert:[220/291] Writing tensor blk.24.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 151
# INFO:convert:[221/291] Writing tensor blk.24.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 151
# INFO:convert:[222/291] Writing tensor blk.24.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 152
# INFO:convert:[223/291] Writing tensor blk.24.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 152
# INFO:convert:[224/291] Writing tensor blk.24.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 156
# INFO:convert:[225/291] Writing tensor blk.24.attn_norm.weight                | size   3072           | type F32  | T+ 160
# INFO:convert:[226/291] Writing tensor blk.24.ffn_norm.weight                 | size   3072           | type F32  | T+ 160
# INFO:convert:[227/291] Writing tensor blk.25.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 160
# INFO:convert:[228/291] Writing tensor blk.25.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 161
# INFO:convert:[229/291] Writing tensor blk.25.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 161
# INFO:convert:[230/291] Writing tensor blk.25.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 161
# INFO:convert:[231/291] Writing tensor blk.25.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 161
# INFO:convert:[232/291] Writing tensor blk.25.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 165
# INFO:convert:[233/291] Writing tensor blk.25.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 167
# INFO:convert:[234/291] Writing tensor blk.25.attn_norm.weight                | size   3072           | type F32  | T+ 167
# INFO:convert:[235/291] Writing tensor blk.25.ffn_norm.weight                 | size   3072           | type F32  | T+ 167
# INFO:convert:[236/291] Writing tensor blk.26.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 167
# INFO:convert:[237/291] Writing tensor blk.26.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 168
# INFO:convert:[238/291] Writing tensor blk.26.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 168
# INFO:convert:[239/291] Writing tensor blk.26.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 168
# INFO:convert:[240/291] Writing tensor blk.26.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 168
# INFO:convert:[241/291] Writing tensor blk.26.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 171
# INFO:convert:[242/291] Writing tensor blk.26.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 171
# INFO:convert:[243/291] Writing tensor blk.26.attn_norm.weight                | size   3072           | type F32  | T+ 172
# INFO:convert:[244/291] Writing tensor blk.26.ffn_norm.weight                 | size   3072           | type F32  | T+ 172
# INFO:convert:[245/291] Writing tensor blk.27.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 172
# INFO:convert:[246/291] Writing tensor blk.27.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 172
# INFO:convert:[247/291] Writing tensor blk.27.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 172
# INFO:convert:[248/291] Writing tensor blk.27.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 172
# INFO:convert:[249/291] Writing tensor blk.27.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 172
# INFO:convert:[250/291] Writing tensor blk.27.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 173
# INFO:convert:[251/291] Writing tensor blk.27.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 178
# INFO:convert:[252/291] Writing tensor blk.27.attn_norm.weight                | size   3072           | type F32  | T+ 178
# INFO:convert:[253/291] Writing tensor blk.27.ffn_norm.weight                 | size   3072           | type F32  | T+ 178
# INFO:convert:[254/291] Writing tensor blk.28.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 178
# INFO:convert:[255/291] Writing tensor blk.28.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 178
# INFO:convert:[256/291] Writing tensor blk.28.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 181
# INFO:convert:[257/291] Writing tensor blk.28.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 181
# INFO:convert:[258/291] Writing tensor blk.28.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 181
# INFO:convert:[259/291] Writing tensor blk.28.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 184
# INFO:convert:[260/291] Writing tensor blk.28.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 184
# INFO:convert:[261/291] Writing tensor blk.28.attn_norm.weight                | size   3072           | type F32  | T+ 189
# INFO:convert:[262/291] Writing tensor blk.28.ffn_norm.weight                 | size   3072           | type F32  | T+ 189
# INFO:convert:[263/291] Writing tensor blk.29.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 189
# INFO:convert:[264/291] Writing tensor blk.29.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 190
# INFO:convert:[265/291] Writing tensor blk.29.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 190
# INFO:convert:[266/291] Writing tensor blk.29.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 190
# INFO:convert:[267/291] Writing tensor blk.29.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 190
# INFO:convert:[268/291] Writing tensor blk.29.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 191
# INFO:convert:[269/291] Writing tensor blk.29.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 191
# INFO:convert:[270/291] Writing tensor blk.29.attn_norm.weight                | size   3072           | type F32  | T+ 191
# INFO:convert:[271/291] Writing tensor blk.29.ffn_norm.weight                 | size   3072           | type F32  | T+ 191
# INFO:convert:[272/291] Writing tensor blk.30.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 191
# INFO:convert:[273/291] Writing tensor blk.30.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 194
# INFO:convert:[274/291] Writing tensor blk.30.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 195
# INFO:convert:[275/291] Writing tensor blk.30.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 197
# INFO:convert:[276/291] Writing tensor blk.30.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 198
# INFO:convert:[277/291] Writing tensor blk.30.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 200
# INFO:convert:[278/291] Writing tensor blk.30.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 200
# INFO:convert:[279/291] Writing tensor blk.30.attn_norm.weight                | size   3072           | type F32  | T+ 200
# INFO:convert:[280/291] Writing tensor blk.30.ffn_norm.weight                 | size   3072           | type F32  | T+ 200
# INFO:convert:[281/291] Writing tensor blk.31.attn_q.weight                   | size   3072 x   3072  | type F16  | T+ 200
# INFO:convert:[282/291] Writing tensor blk.31.attn_k.weight                   | size   3072 x   3072  | type F16  | T+ 200
# INFO:convert:[283/291] Writing tensor blk.31.attn_v.weight                   | size   3072 x   3072  | type F16  | T+ 201
# INFO:convert:[284/291] Writing tensor blk.31.attn_output.weight              | size   3072 x   3072  | type F16  | T+ 201
# INFO:convert:[285/291] Writing tensor blk.31.ffn_gate.weight                 | size   8192 x   3072  | type F16  | T+ 202
# INFO:convert:[286/291] Writing tensor blk.31.ffn_up.weight                   | size   8192 x   3072  | type F16  | T+ 202
# INFO:convert:[287/291] Writing tensor blk.31.ffn_down.weight                 | size   3072 x   8192  | type F16  | T+ 206
# INFO:convert:[288/291] Writing tensor blk.31.attn_norm.weight                | size   3072           | type F32  | T+ 206
# INFO:convert:[289/291] Writing tensor blk.31.ffn_norm.weight                 | size   3072           | type F32  | T+ 206
# INFO:convert:[290/291] Writing tensor output_norm.weight                     | size   3072           | type F32  | T+ 206
# INFO:convert:[291/291] Writing tensor output.weight                          | size  32064 x   3072  | type F16  | T+ 208
# INFO:convert:Wrote deepanshdj/dj-phi-3-F16-GGUF-unsloth.F16.gguf
# Unsloth: Conversion completed! Output location: ./deepanshdj/dj-phi-3-F16-GGUF-unsloth.F16.gguf
# Unsloth: Uploading GGUF to Huggingface Hub...
# dj-phi-3-F16-GGUF-unsloth.F16.gguf:   0%|          | 0.00/7.64G [00:00<?, ?B/s]
# Saved GGUF to https://huggingface.co/deepanshdj/dj-phi-3-F16-GGUF

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
